# %%
import pandas as pd

df = pd.read_excel("C://Users//User//Documents//Movies.xlsx")

df
# Out:
#         ID                  Title ReleaseDate           Director  \
# 0        1          Jurassic Park  1993-06-11   Steven Spielberg
# 1        2             Spider-Man  2002-05-03          Sam Raimi
# 2        3              King Kong  2005-12-14      Peter Jackson
# 3        5       Superman Returns  2006-07-14       Bryan Singer
# 4        6                Titanic  1998-01-23      James Cameron
# ...    ...                    ...         ...                ...
# 1195  1674     Samson and Delilah  1949-12-21   Cecil B. DeMille
# 1196  1675  The NeverEnding Story  1984-04-06  Wolfgang Peterson
# 1197  1676             Enemy Mine  1985-12-20  Wolfgang Peterson
# 1198  1677    In the Line of Fire  1993-07-09  Wolfgang Peterson
# 1199  1678               Outbreak  1995-03-10  Wolfgang Peterson
#
#       RunTimeMinutes        Country            Genre Certificate  \
# 0                126  United States        Adventure          PG
# ...

# %%
rows , columns = df.shape

# %%
rows
# Out:
# 1200

# %%
columns
# Out:
# 12

# %%
df.head()
# Out:
#    ID             Title ReleaseDate          Director  RunTimeMinutes  \
# 0   1     Jurassic Park  1993-06-11  Steven Spielberg             126
# 1   2        Spider-Man  2002-05-03         Sam Raimi             121
# 2   3         King Kong  2005-12-14     Peter Jackson             187
# 3   5  Superman Returns  2006-07-14      Bryan Singer             154
# 4   6           Titanic  1998-01-23     James Cameron             194
#
#          Country      Genre Certificate  BudgetDollars  BoxOfficeDollars  \
# 0  United States  Adventure          PG     63000000.0      1.029940e+09
# 1  United States     Action         12A    140000000.0      8.217086e+08
# 2    New Zealand  Adventure         12A    207000000.0      5.505000e+08
# 3  United States     Action         12A    204000000.0      3.910812e+08
# 4  United States    Romance          12    200000000.0      2.186772e+09
#
#    OscarNominations  OscarWins
# 0                 3          3
# 1                 2          0
# ...

# %%
df.head(2)
# Out:
#    ID          Title ReleaseDate          Director  RunTimeMinutes  \
# 0   1  Jurassic Park  1993-06-11  Steven Spielberg             126
# 1   2     Spider-Man  2002-05-03         Sam Raimi             121
#
#          Country      Genre Certificate  BudgetDollars  BoxOfficeDollars  \
# 0  United States  Adventure          PG     63000000.0      1.029940e+09
# 1  United States     Action         12A    140000000.0      8.217086e+08
#
#    OscarNominations  OscarWins
# 0                 3          3
# 1                 2          0

# %%
df.tail(5)
# Out:
#         ID                  Title ReleaseDate           Director  \
# 1195  1674     Samson and Delilah  1949-12-21   Cecil B. DeMille
# 1196  1675  The NeverEnding Story  1984-04-06  Wolfgang Peterson
# 1197  1676             Enemy Mine  1985-12-20  Wolfgang Peterson
# 1198  1677    In the Line of Fire  1993-07-09  Wolfgang Peterson
# 1199  1678               Outbreak  1995-03-10  Wolfgang Peterson
#
#       RunTimeMinutes        Country            Genre Certificate  \
# 1195             128  United States            Drama           U
# 1196              93        Germany          Fantasy           U
# 1197             108  United States  Science Fiction          15
# 1198             128  United States         Thriller          15
# 1199             128  United States         Thriller          15
#
#       BudgetDollars  BoxOfficeDollars  OscarNominations  OscarWins
# 1195      2900000.0        25600000.0                 5          2
# ...

# %%
df[2:5]

# %%
df.columns

# %%
df.column

# %%
df.columns

# %%
df.Title

# %%
df['Title']

# %%
df[['Title','Director']]
# Out:
#                       Title           Director
# 0             Jurassic Park   Steven Spielberg
# 1                Spider-Man          Sam Raimi
# 2                 King Kong      Peter Jackson
# 3          Superman Returns       Bryan Singer
# 4                   Titanic      James Cameron
# ...                     ...                ...
# 1195     Samson and Delilah   Cecil B. DeMille
# 1196  The NeverEnding Story  Wolfgang Peterson
# 1197             Enemy Mine  Wolfgang Peterson
# 1198    In the Line of Fire  Wolfgang Peterson
# 1199               Outbreak  Wolfgang Peterson
#
# [1200 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Title', 'ReleaseDate', 'Director', 'RunTimeMinutes', 'Country',
#        'Genre', 'Certificate', 'BudgetDollars', 'BoxOfficeDollars',
#        'OscarNominations', 'OscarWins'],
#       dtype='object')

# %%
df['BudgetDollars'].max()

df['BudgetDollars'].min()

df.describe()
# Out:
#                 ID  RunTimeMinutes  BudgetDollars  BoxOfficeDollars  \
# count  1200.000000     1200.000000   1.076000e+03      1.083000e+03
# mean    833.649167      119.666667   5.506225e+07      2.362876e+08
# std     558.618331       24.674540   6.145963e+07      2.917956e+08
# min       1.000000       68.000000   3.000000e+04      2.724450e+05
# 25%     307.750000      102.000000   8.200000e+06      4.233279e+07
# 50%     705.000000      116.000000   3.000000e+07      1.243000e+08
# 75%    1373.250000      131.250000   8.200000e+07      3.316000e+08
# max    1678.000000      260.000000   3.785000e+08      2.788000e+09
#
#        OscarNominations    OscarWins
# count       1200.000000  1200.000000
# mean           1.835833     0.569167
# std            2.980148     1.491220
# min            0.000000     0.000000
# 25%            0.000000     0.000000
# 50%            0.000000     0.000000
# 75%            3.000000     0.000000
# max           14.000000    11.000000

# %%
df[df.ID >= 3]
# Out:
#         ID                  Title ReleaseDate           Director  \
# 2        3              King Kong  2005-12-14      Peter Jackson
# 3        5       Superman Returns  2006-07-14       Bryan Singer
# 4        6                Titanic  1998-01-23      James Cameron
# 5        7          Evan Almighty  2007-06-22        Tom Shadyac
# 6        8             Waterworld  1995-07-28     Kevin Reynolds
# ...    ...                    ...         ...                ...
# 1195  1674     Samson and Delilah  1949-12-21   Cecil B. DeMille
# 1196  1675  The NeverEnding Story  1984-04-06  Wolfgang Peterson
# 1197  1676             Enemy Mine  1985-12-20  Wolfgang Peterson
# 1198  1677    In the Line of Fire  1993-07-09  Wolfgang Peterson
# 1199  1678               Outbreak  1995-03-10  Wolfgang Peterson
#
#       RunTimeMinutes        Country            Genre Certificate  \
# 2                187    New Zealand        Adventure         12A
# ...

# %%
df[df.BudgetDollars == df["BudgetDollars"].max()]
# Out:
#       ID                                        Title ReleaseDate  \
# 294  302  Pirates of the Caribbean: On Stranger Tides  2011-05-20
#
#          Director  RunTimeMinutes        Country      Genre Certificate  \
# 294  Rob Marshall             137  United States  Adventure         12A
#
#      BudgetDollars  BoxOfficeDollars  OscarNominations  OscarWins
# 294    378500000.0      1.046000e+09                 0          0

# %%
df[df.BudgetDollars == df["BudgetDollars"].min()]
# Out:
#        ID         Title ReleaseDate      Director  RunTimeMinutes  \
# 842  1316  Down Terrace  2009-09-21  Ben Wheatley              93
#
#             Country  Genre Certificate  BudgetDollars  BoxOfficeDollars  \
# 842  United Kingdom  Crime          15        30000.0               NaN
#
#      OscarNominations  OscarWins
# 842                 0          0
